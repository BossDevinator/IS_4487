# %% [markdown]
# <a href="https://colab.research.google.com/github/BossDevinator/IS_4487/blob/main/Labs/Scripts/lab4_social_media_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Lab 4
#
# ## Outline
#
# Repeat exercises from Lab 2, but with the *X SuperBowl* social media dataset
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Labs/Scripts/lab4_social_media_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # X API Data Dictionary
# See https://developer.x.com/en/docs/x-api/data-dictionary/introduction

# %% [markdown]
# ## Load Libraries
#
# ➡️ Assignment Tasks
# - Load any necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Data into Dataframe
#
# ➡️ Assignment Tasks
# - Import data from the X SuperBowl dataset into a dataframe (in GitHub go to Labs > DataSets)
# - Describe or profile the dataframe
# - Make sure you watch for line breaks and emojis that might cause problems with the data import

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Stan-Pugsley/is_4487_base/main/Labs/DataSets/x_superbowl.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                     created_at  \
# 0     2024-02-12T01:52:00.000Z
# 1     2024-02-12T01:20:00.000Z
# 2     2024-02-12T01:15:36.000Z
# 3     2024-02-12T01:15:17.000Z
# 4     2024-02-12T02:01:18.000Z
# ...                        ...
# 9372  2024-02-12T01:59:49.000Z
# 9373  2024-02-12T01:59:25.000Z
# 9374  2024-02-12T01:59:22.000Z
# 9375  2024-02-12T01:57:11.000Z
# 9376  2024-02-12T01:56:56.000Z
#
#                                                    text      conversation_id  \
# 0      Fireman at the Superbowl https://t.co/AjqmmHvDQl  1756858660205015180
# 1     Watch the #SuperBowl ads for #GhostsCBS, #Fire...  1756850607573623005
# 2     Watch the #Tracker and #FireCountry #SuperBowl...  1756828194647527707
# 3     I can't believe Norman Bates brother is a fire...  1756849420442681386
# 4     👉 @NFL &amp; @fifa may be occut but some of th...  1756861000693739724
# ...                                                 ...                  ...
# 9372  RT @AlertesInfos: 🏈🇺🇸 Le prix d'un spot public...  1756860629007086042
# 9373  @lauhaim diffusé en direct sur @M6 en France !...  1756853050797355301
# 9374  lmao my superbowl is making jalapeno cheese bu...  1756860513693086043
# 9375  Olives pepperoni onions cheese pine apple saus...  1756859967767011714
# 9376  3am in France. Superbowl en direct (live) on c...  1756859904193667127
#
#        edit_history_tweet_ids  possibly_sensitive reply_settings lang  \
# 0     ['1756858660205015180']               False       everyone   en
# 1     ['1756850607573623005']               False       everyone   en
# 2     ['1756849502018064847']               False       everyone   en
# 3     ['1756849420442681386']               False       everyone   en
# 4     ['1756861000693739724']               False       everyone   en
# ...                       ...                 ...            ...  ...
# 9372  ['1756860629007086042']               False       everyone   fr
# 9373  ['1756860527827996728']               False       everyone   fr
# 9374  ['1756860513693086043']               False       everyone   en
# 9375  ['1756859967767011714']               False       everyone   en
# 9376  ['1756859904193667127']               False       everyone   fr
#
#                 author_id                   id  \
# 0               520886265  1756858660205015180
# 1                18090782  1756850607573623005
# 2                14541151  1756849502018064847
# 3               103086570  1756849420442681386
# 4     1747783752418197504  1756861000693739724
# ...                   ...                  ...
# 9372   967770971439583233  1756860629007086042
# 9373            128845800  1756860527827996728
# 9374  1217883726232936448  1756860513693086043
# 9375             19308642  1756859967767011714
# 9376            985703126  1756859904193667127
#
#                                           entities.urls  ...  \
# 0     [{'start': 25, 'end': 48, 'url': 'https://t.co...  ...
# 1     [{'start': 86, 'end': 109, 'url': 'https://t.c...  ...
# 2     [{'start': 65, 'end': 88, 'url': 'https://t.co...  ...
# 3                                                   NaN  ...
# 4     [{'start': 247, 'end': 270, 'url': 'https://t....  ...
# ...                                                 ...  ...
# 9372                                                NaN  ...
# 9373                                                NaN  ...
# 9374                                                NaN  ...
# 9375  [{'start': 125, 'end': 148, 'url': 'https://t....  ...
# 9376  [{'start': 69, 'end': 92, 'url': 'https://t.co...  ...
#
#      in_reply_to_user_id         username                     name  \
# 0                    NaN      jerkinjerky  Spencer's Jerkin' Jerky
# 1                    NaN   GiveMeMyRemote           GiveMeMyRemote
# 2             14541151.0    marisaroffman           Marisa Roffman
# 3                    NaN    geekmentality      Geek Mentality Mike
# 4                    NaN    ryanadamtexas          Ryan Adam Texas
# ...                  ...              ...                      ...
# 9372                 NaN  MATTEOM91836712            MATTEO MATTEO
# 9373          49783304.0       Themistone                 Mistone©
# 9374                 NaN    theheartlines              lady hope 🫀
# 9375                 NaN     babyduckeyes            🌈RainbowRiot⚡
# 9376                 NaN       ToadNation               ToadNation
#
#                             location    keyword  \
# 0                    Gainesville, FL   AllState
# 1           Wherever the TV news is.   AllState
# 2                                NaN   AllState
# 3                      Massachusetts   AllState
# 4                  Dallas, Texas USA   AllState
# ...                              ...        ...
# 9372  Bouches-du-Rhône, Provence-Alp  Budweiser
# 9373                        Orleen's  Budweiser
# 9374      in the kitchen cooking 🪦🕊️  Budweiser
# 9375                 ⚓Arizona, USA🇺🇸  Budweiser
# 9376                             NaN  Budweiser
#
#                                       entities.mentions  attachments.poll_ids  \
# 0                                                   NaN                   NaN
# 1                                                   NaN                   NaN
# 2                                                   NaN                   NaN
# 3                                                   NaN                   NaN
# 4     [{'start': 2, 'end': 6, 'username': 'NFL', 'id...                   NaN
# ...                                                 ...                   ...
# 9372  [{'start': 3, 'end': 16, 'username': 'AlertesI...                   NaN
# 9373  [{'start': 0, 'end': 8, 'username': 'lauhaim',...                   NaN
# 9374                                                NaN                   NaN
# 9375                                                NaN                   NaN
# 9376                                                NaN                   NaN
#
#       attachments.media_source_tweet_id  entities.cashtags  \
# 0                                   NaN                NaN
# 1                                   NaN                NaN
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                                   NaN                NaN
# ...                                 ...                ...
# 9372                                NaN                NaN
# 9373                                NaN                NaN
# 9374                                NaN                NaN
# 9375                                NaN                NaN
# 9376                                NaN                NaN
#
#       withheld.country_codes
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 9372                     NaN
# 9373                     NaN
# 9374                     NaN
# 9375                     NaN
# 9376                     NaN
#
# [9377 rows x 34 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9377 entries, 0 to 9376
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   created_at                         9377 non-null   object
#  1   text                               9377 non-null   object
#  2   conversation_id                    9377 non-null   int64
#  3   edit_history_tweet_ids             9377 non-null   object
#  4   possibly_sensitive                 9377 non-null   bool
#  5   reply_settings                     9377 non-null   object
#  6   lang                               9377 non-null   object
#  7   author_id                          9377 non-null   int64
#  8   id                                 9377 non-null   int64
#  9   entities.urls                      3326 non-null   object
#  10  entities.annotations               8179 non-null   object
#  11  edit_controls.edits_remaining      9377 non-null   int64
#  12  edit_controls.is_edit_eligible     9377 non-null   bool
#  13  edit_controls.editable_until       9377 non-null   object
#  14  geo.place_id                       239 non-null    object
#  15  attachments.media_keys             2326 non-null   object
#  16  public_metrics.retweet_count       9377 non-null   int64
#  17  public_metrics.reply_count         9377 non-null   int64
#  18  public_metrics.like_count          9377 non-null   int64
#  19  public_metrics.quote_count         9377 non-null   int64
#  20  public_metrics.bookmark_count      9377 non-null   int64
#  21  public_metrics.impression_count    9377 non-null   int64
#  22  entities.hashtags                  7376 non-null   object
#  23  referenced_tweets                  5908 non-null   object
#  24  in_reply_to_user_id                1180 non-null   float64
#  25  username                           9377 non-null   object
#  26  name                               9377 non-null   object
#  27  location                           6258 non-null   object
#  28  keyword                            9377 non-null   object
#  29  entities.mentions                  6322 non-null   object
#  30  attachments.poll_ids               11 non-null     object
#  31  attachments.media_source_tweet_id  1323 non-null   object
#  32  entities.cashtags                  58 non-null     object
#  33  withheld.country_codes             3 non-null      object
# dtypes: bool(2), float64(1), int64(10), object(21)
# memory usage: 2.3+ MB

# %%
df.shape
# Out:
# (9377, 34)

# %%
df.head(10)
# Out:
#                  created_at  \
# 0  2024-02-12T01:52:00.000Z
# 1  2024-02-12T01:20:00.000Z
# 2  2024-02-12T01:15:36.000Z
# 3  2024-02-12T01:15:17.000Z
# 4  2024-02-12T02:01:18.000Z
# 5  2024-02-12T00:41:12.000Z
# 6  2024-02-12T00:18:22.000Z
# 7  2024-02-12T00:16:14.000Z
# 8  2024-02-12T00:12:32.000Z
# 9  2024-02-12T00:09:37.000Z
#
#                                                 text      conversation_id  \
# 0   Fireman at the Superbowl https://t.co/AjqmmHvDQl  1756858660205015180
# 1  Watch the #SuperBowl ads for #GhostsCBS, #Fire...  1756850607573623005
# 2  Watch the #Tracker and #FireCountry #SuperBowl...  1756828194647527707
# 3  I can't believe Norman Bates brother is a fire...  1756849420442681386
# 4  👉 @NFL &amp; @fifa may be occut but some of th...  1756861000693739724
# 5  🔴#XTREMO| #LionelMessi, #DanMarino and #JasonS...  1756840844651270213
# 6  #LionelMessi, Dan "The Man" Marino and Jason S...  1756835100057071637
# 7  #whataretheodds #SuperBowl #pringels #LionelMe...  1756834563093868614
# 8  #michelob #LionelMessi #Deadpool3 #Wrexham #Su...  1756833630674944179
# 9  #Popeyes with #KenJeong. Okay.\n#Michelob with...  1756828268622225492
#
#     edit_history_tweet_ids  possibly_sensitive reply_settings lang  \
# 0  ['1756858660205015180']               False       everyone   en
# 1  ['1756850607573623005']               False       everyone   en
# 2  ['1756849502018064847']               False       everyone   en
# 3  ['1756849420442681386']               False       everyone   en
# 4  ['1756861000693739724']               False       everyone   en
# 5  ['1756840844651270213']                True       everyone   es
# 6  ['1756835100057071637']               False       everyone   en
# 7  ['1756834563093868614']               False       everyone  qme
# 8  ['1756833630674944179']               False       everyone  qme
# 9  ['1756832898051694733']               False       everyone   en
#
#              author_id                   id  \
# 0            520886265  1756858660205015180
# 1             18090782  1756850607573623005
# 2             14541151  1756849502018064847
# 3            103086570  1756849420442681386
# 4  1747783752418197504  1756861000693739724
# 5            315278595  1756840844651270213
# 6            116547240  1756835100057071637
# 7  1661494276625162240  1756834563093868614
# 8  1661494276625162240  1756833630674944179
# 9            105009063  1756832898051694733
#
#                                        entities.urls  ... in_reply_to_user_id  \
# 0  [{'start': 25, 'end': 48, 'url': 'https://t.co...  ...                 NaN
# 1  [{'start': 86, 'end': 109, 'url': 'https://t.c...  ...                 NaN
# 2  [{'start': 65, 'end': 88, 'url': 'https://t.co...  ...          14541151.0
# 3                                                NaN  ...                 NaN
# 4  [{'start': 247, 'end': 270, 'url': 'https://t....  ...                 NaN
# 5  [{'start': 179, 'end': 202, 'url': 'https://t....  ...                 NaN
# 6  [{'start': 118, 'end': 141, 'url': 'https://t....  ...                 NaN
# 7  [{'start': 79, 'end': 102, 'url': 'https://t.c...  ...                 NaN
# 8  [{'start': 54, 'end': 77, 'url': 'https://t.co...  ...                 NaN
# 9                                                NaN  ...         105009063.0
#
#          username                     name                  location  \
# 0     jerkinjerky  Spencer's Jerkin' Jerky           Gainesville, FL
# 1  GiveMeMyRemote           GiveMeMyRemote  Wherever the TV news is.
# 2   marisaroffman           Marisa Roffman                       NaN
# 3   geekmentality      Geek Mentality Mike             Massachusetts
# 4   ryanadamtexas          Ryan Adam Texas         Dallas, Texas USA
# 5    AhoraTabasco   Ahora Tabasco Noticias     Villahermosa, Tabasco
# 6          TooFab                   TooFab                       NaN
# 7      JimKruse01                Jim Kruse                       NaN
# 8      JimKruse01                Jim Kruse                       NaN
# 9   BlackDesignTw      BlackDesignTw!tter™                   On Tour
#
#     keyword                                  entities.mentions  \
# 0  AllState                                                NaN
# 1  AllState                                                NaN
# 2  AllState                                                NaN
# 3  AllState                                                NaN
# 4  AllState  [{'start': 2, 'end': 6, 'username': 'NFL', 'id...
# 5  AllState                                                NaN
# 6  AllState                                                NaN
# 7  AllState                                                NaN
# 8  AllState                                                NaN
# 9  AllState                                                NaN
#
#    attachments.poll_ids  attachments.media_source_tweet_id  entities.cashtags  \
# 0                   NaN                                NaN                NaN
# 1                   NaN                                NaN                NaN
# 2                   NaN                                NaN                NaN
# 3                   NaN                                NaN                NaN
# 4                   NaN                                NaN                NaN
# 5                   NaN                                NaN                NaN
# 6                   NaN                                NaN                NaN
# 7                   NaN                                NaN                NaN
# 8                   NaN                                NaN                NaN
# 9                   NaN                                NaN                NaN
#
#    withheld.country_codes
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Prepare Data
#
# ➡️ Assignment Tasks
# - Convert any numbers, such as user_mentioned, from strings into numbers
# - Reduce the variables in your dataframe to only those that have useful data
# - Optional: Locate outliers in any of the variables.   Filter them out if they are mistakes; keep them if they are exceptional cases.

# %%
df_new = df[['created_at', 'text', 'possibly_sensitive', 'reply_settings', 'lang', 'username', 'name', 'location', 'keyword', 'public_metrics.retweet_count', 'public_metrics.reply_count', 'public_metrics.like_count', 'public_metrics.quote_count', 'public_metrics.bookmark_count', 'public_metrics.impression_count', 'entities.hashtags']]
df_new.sort_values(by='public_metrics.like_count', ascending=False).head()
# Out:
#                     created_at  \
# 6793  2024-02-12T03:36:28.000Z
# 1178  2024-02-12T03:06:00.000Z
# 8047  2024-02-12T03:40:03.000Z
# 1138  2024-02-12T03:09:24.000Z
# 1245  2024-02-12T02:56:11.000Z
#
#                                                    text  possibly_sensitive  \
# 6793  CBS after pulling off the best script in NFL h...               False
# 1178  📹 | Disney Plus’ new ad ends with “…Ready For ...               False
# 8047  Behind the scenes of Ben Affleck, Matt Damon a...               False
# 1138  📺 | A @DisneyPlus commercial aired during the ...               False
# 1245  PERFEITO! Novo comercial do Disney+ relembra a...               False
#
#      reply_settings lang         username                    name   location  \
# 6793       everyone   en            _Xins                      ‏ً  Recovery
# 1178       everyone   en         TSwiftLA  Taylor Swift Updates 🤍  Worldwide
# 8047       everyone   en  BenniferUpdates        Bennifer Updates        NaN
# 1138       everyone   en         TSwiftNZ     Taylor Swift News 🤍  WORLDWIDE
# 1245       everyone   pt  almanaquedisney        Almanaque Disney     Brasil
#
#         keyword  public_metrics.retweet_count  public_metrics.reply_count  \
# 6793  Bud Light                           189                          38
# 1178     BetMgM                           145                          11
# 8047  Bud Light                           120                           5
# 1138     BetMgM                            76                           8
# 1245     BetMgM                            73                           8
#
#       public_metrics.like_count  public_metrics.quote_count  \
# 6793                       2043                           2
# 1178                       1333                          16
# 8047                        990                           6
# 1138                        858                           5
# 1245                        635                          17
#
#       public_metrics.bookmark_count  public_metrics.impression_count  \
# 6793                            127                           246031
# 1178                             50                            66622
# 8047                             96                            68419
# 1138                             20                            46862
# 1245                             48                            22748
#
#                                      entities.hashtags
# 6793    [{'start': 53, 'end': 63, 'tag': 'SuperBowl'}]
# 1178    [{'start': 51, 'end': 61, 'tag': 'SuperBowl'}]
# 8047    [{'start': 71, 'end': 81, 'tag': 'SuperBowl'}]
# 1138    [{'start': 46, 'end': 56, 'tag': 'SuperBowl'}]
# 1245  [{'start': 125, 'end': 135, 'tag': 'SuperBowl'}]

# %% [markdown]
# ## Summarize Data
#
# ➡️ Assignment Tasks
# - Create at least two charts to summarize and visualize the data
# - Examples include: Number of posts per device; top 10 posts with highest engagement

# %%
#chart 1

# %%
top_keywords = df_new['keyword'].value_counts().head(5)
top_keywords.plot(kind='bar')
plt.title('Top 5 Keywords')
plt.xlabel('Keywords')
plt.ylabel('Number of Posts')
plt.show()

# %%
#chart 2

# %%
top_100 = df_new.sort_values(by='public_metrics.like_count', ascending=False).head(100)
sensitive_count = top_100_liked['possibly_sensitive'].sum()
not_sensitive_count = 100 - sensitive_count
labels = ['Possibly Sensitive', 'Not Possibly Sensitive']
sizes = [sensitive_count, not_sensitive_count]
plt.pie(sizes, labels=labels, autopct='%1.3f%%')
plt.title('Top 100 Liked Posts by Possibly Sensitive')
plt.show()
